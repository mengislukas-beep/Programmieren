# %%
a = 20 + 20
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
print(a**2)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
x = np.linspace(-10, 10, 10000)
y = np.sin(1/x)

plt.plot(x, y)
plt.show()
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
liste = [i for i in range(10)]
liste = np.array(liste)
print(liste**2 + 3*liste + 5)
# Out:
# [  5   9  15  23  33  45  59  75  93 113]

# %%
liste = np.random.randint(0,100, size=100)

# %%
print(liste)
# Out:
# [25 19 87 14 21 96 49 69 92 72 59 59 66 22 51 34 33 26 88 10 97 15 66 74
#   2 43 74 58 52 53 27 57 40 38 44 29 81 12 25 41  8 40 81 40 10 69 82 17
#  46 23  3 66 34 14  8 42  2  4 58 13 76 74 84 96 12 91  1 34 75 29 25 54
#  63  4 59 68 39  3 15 88 71 45 73 80 11 72 92 89 59 99 74  9 63 33 76 26
#  34  1 93 51]

# %%
liste = np.random.randint(0,100, size=100)
print(np.cov(liste))
print(np.mean(liste))
print(np.median(liste))
print(np.std(liste))
print(np.var(liste))
# Out:
# 868.0993939393943
# 48.96
# 46.5
# 29.315838722438084
# 859.4184000000001
